# %% [markdown]
# # **Project Name**    - **Hotel Booking Analysis**

# %% [markdown]
# ## Project Summary
# Study of Hotel bookings related data is vital for any hospitality business as it gives insight into booking behaviour of customers as well as channels through which bookings are made.
#
# This project involves the analysis of the provided data set pertaining to Hotel bookings for **City** and **Resort Hotels**.
#
# Project activities have been categorised as under:
# 1.   Defining the problem statement i.e. Business Objective of the study.
# 2.   Collection and preparation of data by data cleaning , treating  outliers etc.
# 3.   Perform exploratory data analysis(EDA) through a deep study of relationship between different features, generate new variables based on need inline with related business objectives. Present the data in easily understandable form.
# 4.   Provide observations as well as recommendations based on the EDA.

# %% [markdown]
# ## Problem Statement
#
# An effort has been made in this project to analyse various aspects of booking behaviour by customers to answer various business challenges faced by hotel through rigorous study of:
#
# 1. Origination of guests i.e where do guests originally come from so that footfall from  those countries can be further increased through additional public advertisements. Extra effort can also be made to retain them through personalised contact through emails, phone calls etc even after they leave.
#
# 2. Monthly booking pattern.
#
# 3. Duration of the stay by various guests to provide smart pricing structure to increase stay.
#
# 4. Average Daily rate dependency on season,room type & allotment of demanded room type to optimise the price for greater occupancy.
#
# 5. Booking cancellation pattern considering various parameters like hotel type, lead time, season, deposit etc. to plan overbooking as well as devise means like penalty amount etc.
#
# 6. Customer retention pattern based on Hotel type to lay special emphasis on improving the experience to retain the customers.

# %% [markdown]
# # Understanding Data

# %%
# Importing all import python libraries
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
 # Loading the Dataset
hotel_df = pd.read_csv("hotel_bookings.csv")

# %%
 # DataSet first look
hotel_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
hotel_df.shape
# Out:
# (119390, 32)

# %%
# To view all columns
pd.set_option('display.max_columns',32)

# %%
hotel_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
# Checking Basic info
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# We see that there are 32 columns in the dataframe and some columns like 'children', 'company', 'country' and 'agent' have null values.

# %% [markdown]
# ## Variables Description
#
# * **Hotel:**  H1= Resort Hotel, H2= City Hotel
# * **is_canceled** : If the booking was canceled(1) or not(0)
# * **lead_time** : Number of days that elapsed between the entering date of the  booking into the PMS(Property Management System) and the arrival date
# * **arrival_date_year** : Year of arrival date.
# * **arrival_date_month** : Month of arrival date.
# * **arrival_date_week_number** : Week number for arrival date.
# * **arrival_date_day_of_month**: Which day of the months guest is arriving.
# * **stays_in_weekend_nights**: Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel.
# * **stays_in_week_nights**: Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel.
# * **adults** : Number of adults.
# * **children** : Number of children.
# * **babies** : Number of babies.
# * **meal**: kind of meal opted for.
# * **country** : Country code.
# * **market_segment**: Through which channel hotels were booked.
# * **distribution_channel** : How the customer accessed the stay- Corporate Booking/Direct/TA.TO
# * **is_repeated_guest** : The values indicating if the booking name was from a repeated guest (1) or not (0).
# * **previous_cancellations** : Was there a cancellation before.
# * **previous_bookings_not_canceled** : Count of previous bookings not cancelled.
# * **reserved_room_type** : Code of room type reserved.
# * **assigned_room_type** : Code for the type of room assigned to the booking.
# * **booking_changes** : Count of changes made to booking.
# * **deposit_type** : Deposit type.
# * **agent** : If the booking happens through agents or not.
# * **company** : If the booking happens through companies, the company ID that made the booking or responsible for paying the booking.
# * **days_in_waiting_list** : Number of days the booking was on the waiting list before the confirmation to the customer.
# * **customer_type** : Booking type like Transient – Transient-Party – Contract – Group.
# * **adr** : Average Daily Rates that described via way of means of dividing the sum of all accommodations transactions using entire numbers of staying nights.
# * **required_car_parking_spaces** : How many parking areas are necessary for the customers.
# * **total_of_special_requests** : Total unique requests from consumers.
# * **reservation_status**: The last status of reservation, assuming one of three categories: Canceled – booking was cancelled by the customer; Check-Out;No-Show.
# * **reservation_status_date**: The last status date.

# %%
# Creating a copy of dataframe

copy_hotel_df = hotel_df.copy()

# %% [markdown]
# First of all we will try to understand the meaning of all columns of the dataframe. \
# For this we will see the unique values attained by each column whose meaning we are unable to understand.

# %%
copy_hotel_df.nunique()
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             17
# stays_in_week_nights                35
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            177
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# agent                              333
# ...

# %%
copy_hotel_df['hotel'].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
copy_hotel_df['is_canceled'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
copy_hotel_df['arrival_date_year'].unique()
# Out:
# array([2015, 2016, 2017], dtype=int64)

# %%
copy_hotel_df['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)

# %%
copy_hotel_df['market_segment'].unique()
# Out:
# array(['Direct', 'Corporate', 'Online TA', 'Offline TA/TO',
#        'Complementary', 'Groups', 'Undefined', 'Aviation'], dtype=object)

# %%
copy_hotel_df['distribution_channel'].unique()
# Out:
# array(['Direct', 'Corporate', 'TA/TO', 'Undefined', 'GDS'], dtype=object)

# %%
copy_hotel_df['children'].unique()    # This column has 0 as well as null values
# Out:
# array([ 0.,  1.,  2., 10.,  3., nan])

# %% [markdown]
# ## Data Preparation
#
# Cleaning data is crucial step before EDA as it will remove the ambigous data that can affect the outcome of EDA.
#
# While cleaning data we will perform following steps:
# 1) Remove duplicate rows
# 2) Handling missing values.
# 3) Convert columns to appropriate datatypes.
# 4) Adding important columns

# %% [markdown]
# ###  Step 1: Removing Duplicate Rows

# %%
copy_hotel_df[copy_hotel_df.duplicated()].shape   # Show no. of rows of duplicate rows duplicate rows
# Out:
# (31994, 32)

# %%
# Dropping duplicate values
copy_hotel_df.drop_duplicates(inplace = True)

# %%
copy_hotel_df.shape
# Out:
# (87396, 32)

# %% [markdown]
# ### Step 2: Handling Missing Values

# %%
# Columns having missing values.
copy_hotel_df.isnull().sum().sort_values(ascending = False)[:6]
# Out:
# company               82137
# agent                 12193
# country                 452
# children                  4
# reserved_room_type        0
# assigned_room_type        0
# dtype: int64

# %% [markdown]
# Since, company and agent columns have comany number and agent numbers as data. There may be some cases when customer did not booked hotel via any agent or via any company. So in that case values can be null under these columns.
# We will replace null values by 0 in these columns

# %%
copy_hotel_df[['company','agent']] = copy_hotel_df[['company','agent']].fillna(0)

# %%
copy_hotel_df['children'].unique()
# Out:
# array([ 0.,  1.,  2., 10.,  3., nan])

# %% [markdown]
# This column 'children' has 0 as value which means 0 children were present in group of customers who made that transaction. \
# So, 'nan' values are the missing values due to error of recording data. \
#  \
# We will replace the null values under this column with mean value of children.

# %%
copy_hotel_df['children'].fillna(copy_hotel_df['children'].mean(), inplace = True)

# %% [markdown]
# Next column with missing value is 'country'.
# This column represents the country of oriigin of customer. \
# Since, this column has datatype of string. We will replace the missing value with the mode of 'country' column.

# %%
copy_hotel_df['country'].fillna('others', inplace = True)

# %%
# Checking if all null values are removed
copy_hotel_df.isnull().sum().sort_values(ascending = False)[:6]
# Out:
# hotel                          0
# is_canceled                    0
# reservation_status             0
# total_of_special_requests      0
# required_car_parking_spaces    0
# adr                            0
# dtype: int64

# %% [markdown]
# There are some rows with total number of adults, children or babies equal to zero. So we will remove such rows.

# %%
copy_hotel_df[copy_hotel_df['adults']+copy_hotel_df['babies']+copy_hotel_df['children'] == 0].shape
# Out:
# (166, 32)

# %%
copy_hotel_df.drop(copy_hotel_df[copy_hotel_df['adults']+copy_hotel_df['babies']+copy_hotel_df['children'] == 0].index, inplace = True)

# %% [markdown]
# ### <b> Step 3: Converting columns to appropriate datatypes. </b>

# %%
# Converting datatype of columns 'children', 'company' and 'agent' from float to int.
copy_hotel_df[['children', 'company', 'agent']] = copy_hotel_df[['children', 'company', 'agent']].astype('int64')

# %%
# changing datatype of column 'reservation_status_date' to data_type.
copy_hotel_df['reservation_status_date'] = pd.to_datetime(copy_hotel_df['reservation_status_date'], format = '%d-%m-%y')

# %% [markdown]
# ### <b> Step 4: Adding important columns. </b>

# %%
# Adding total staying days in hotels
copy_hotel_df['total_stay'] = copy_hotel_df['stays_in_weekend_nights']+copy_hotel_df['stays_in_week_nights']

# Adding total people num as column, i.e. total people num = num of adults + children + babies
copy_hotel_df['total_people'] = copy_hotel_df['adults']+copy_hotel_df['children']+copy_hotel_df['babies']

# %% [markdown]
# We are adding this column so that we can analyse the stay length at hotels.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Lets first find the correlation between the numerical data.
#
#
# Since, columns like **'is_cancelled', 'arrival_date_year', 'arrival_date_week_number', 'arrival_date_day_of_month', 'is_repeated_guest', 'company', 'agent'** are categorical data having numerical type. So we wont need to check them for correlation.
#
# Also, we have added **total_stay** and **total_people** columns. So, we can **remove adults, children, babies, stays_in_weekend_nights, stays_in_week_nights** columns.

# %%
chk_hotel_df = copy_hotel_df[['lead_time','previous_cancellations','previous_bookings_not_canceled','booking_changes','days_in_waiting_list','adr','required_car_parking_spaces','total_of_special_requests','total_stay','total_people']]

# %%
#correlation matrix
corr_hotel_df = chk_hotel_df.corr()
fig, ax = plt.subplots(figsize=(12, 7))
ax.set_title('Correlation Matrix', size = 15)
sns.heatmap(corr_hotel_df,annot = True,fmt='.2f', annot_kws={'size': 10},  vmax=.8, cmap = "vlag", square=True);

# %% [markdown]
# 1) Total stay length and lead time have slight correlation. This may means that for longer hotel stays people generally plan little before the the actual arrival.
#
# 2) adr is slightly correlated with total_people, which makes sense as more no. of people means more revenue, therefore more adr.

# %% [markdown]
# Lets see does length of stay affects the adr.

# %%
plt.figure(figsize = (10,4))
sns.scatterplot(y = 'adr', x = 'total_stay', data = copy_hotel_df)
plt.show()

# %% [markdown]
# We notice that there is an outlier in adr, so we will remove that for better scatter plot

# %%
copy_hotel_df.drop(copy_hotel_df[copy_hotel_df['adr'] > 5000].index, inplace = True)

# %%
plt.figure(figsize = (10,4))
sns.scatterplot(y = 'adr', x = 'total_stay', data = copy_hotel_df)
plt.show()

# %% [markdown]
# From the scatter plot we can see that as length of total_stay increases the adr decreases. This means for longer stay, the better deal for customer can be finalised.

# %% [markdown]
# ## Some straight forward questions

# %% [markdown]
# **Q1) Which agent makes most no. of bookings?**

# %%
temp_df= pd.DataFrame(copy_hotel_df['agent'].value_counts()).reset_index().rename(columns = {'count':'num_of_bookings'}).sort_values(by = 'num_of_bookings', ascending = False)
del_df = temp_df[temp_df['agent'] == 0].index
temp_df.drop(del_df,inplace = True) # 0 represents that booking is not made by an agent
temp_df = temp_df[:10]
temp_df
# Out:
#     agent  num_of_bookings
# 0       9            28721
# 1     240            13028
# 3      14             3342
# 4       7             3294
# 5     250             2779
# 6     241             1644
# 7      28             1493
# 8       8             1383
# 9       1             1228
# 10      6             1117

# %%
sns.barplot(x= 'agent', y = 'num_of_bookings', data = temp_df, order = temp_df.sort_values('num_of_bookings', ascending = False).agent)
plt.title('Number of Bookings by Agents', size = 15)
plt.show()

# %% [markdown]
# Agent no. 9 has made most no. of bookings.

# %% [markdown]
# **Q2) Which room type is in most demand and which room type generate highest adr?**

# %%
copy_hotel_df.shape
# Out:
# (87229, 34)

# %%
# To view all columns
pd.set_option('display.max_columns',34)

# %%
copy_hotel_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2         0       0
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 8))

dfv=sns.countplot(ax = axes[0], x = copy_hotel_df['assigned_room_type'])
dfv.set(title = 'Customers vs Room Types')

# Adding Value
for i in dfv.containers:
    dfv.bar_label(i,)
    
sns.boxplot(ax = axes[1], x = copy_hotel_df['assigned_room_type'], y = copy_hotel_df['adr']).set(title = 'ADR vs Room Type')
plt.show()

# %% [markdown]
# Most demanded room type is A, but better adr rooms are of type H, G and F also. Hotels should increase the no. of room types A and H to maximise revenue.

# %% [markdown]
# **Q3) From which countries most of the customers visit these hotels?**

# %%
grp_by_country = copy_hotel_df.groupby('country')
temp_df = pd.DataFrame(grp_by_country.size()).rename(columns = {0:'no. of bookings'}).sort_values('no. of bookings', ascending = False)
temp_df = temp_df[:10]
dfv = sns.barplot(x = temp_df.index, y = temp_df['no. of bookings'])
dfv.set(title = 'Number of Booking from Different Country')
# Adding Value
for i in dfv.containers:
    dfv.bar_label(i,)
    
plt.show()

# %% [markdown]
# Most of the customers come from Portugal, Great Britain, France and Spain.

# %% [markdown]
# ## <b> (1) Hotel wise analysis </b>

# %% [markdown]
# **Q1) What is percentage of bookings in each hotel?**

# %%
grouped_by_hotel = copy_hotel_df.groupby('hotel')
temp_df = pd.DataFrame(grouped_by_hotel.size()).reset_index().rename(columns = {0:'Booking'})  
temp_df
# Out:
#           hotel  Booking
# 0    City Hotel    53273
# 1  Resort Hotel    33956

# %%
plt.figure(figsize = (8,5))
plt.pie( x = temp_df['Booking'], labels = temp_df['hotel'], autopct='%.1f%%',startangle = 90)
plt.title('Booking (%)age By Hotel')
plt.show()

# %% [markdown]
# **61.1%** bookings are for City hotel and **38.9%** bookings are for Resort hotel.

# %% [markdown]
# **Q2) which hotel seems to make more revenue?**

# %%
Temp_df = grouped_by_hotel['adr'].agg(np.mean).reset_index().rename(columns = {'adr':'avg_adr'})   # calculating average adr
plt.figure(figsize = (8,5))
dfv=sns.barplot(x = Temp_df['hotel'], y = Temp_df['avg_adr'] )
dfv.set(title='Avg ADR vs Hotels')
# Adding Value
for i in dfv.containers:
    dfv.bar_label(i,)
plt.show()

# %% [markdown]
# Avg adr of Resort hotel is slightly lower than that of City hotel. Hence, City hotel seems to be making slightly more revenue.

# %% [markdown]
# **Q3) Which hotel has higher lead time?**

# %%
temp_df = grouped_by_hotel['lead_time'].median().reset_index().rename(columns = {'lead_time':'median_lead_time'})
plt.figure(figsize = (8,5))
dfv = sns.barplot(x = temp_df['hotel'], y = temp_df['median_lead_time'] )
dfv.set(title='Lead Time vs Hotels')
# Adding Value
for i in dfv.containers:
    dfv.bar_label(i,)
plt.show()

# %% [markdown]
# City hotel has slightly higher median lead time. Also median lead time is significantly higher in each case, this means customers generally plan their hotel visits way to early.

# %% [markdown]
# **Q4) What is preferred stay in each hotel?**

# %%
not_canceled = copy_hotel_df[copy_hotel_df['is_canceled'] == 0]
s1 = not_canceled[not_canceled['total_stay'] < 15]
plt.figure(figsize = (10,5))
dfv=sns.countplot(x = s1['total_stay'], hue = s1['hotel'])
dfv.set(title ='Number of stays(in days) by customer in Different Hotel', xlabel='Number of Days', ylabel = 'Customer Count')
plt.show()

# %% [markdown]
# Most common stay length is less than 4 days and generally people prefer City hotel for short stay, but for long stays, Resort Hotel is preferred.

# %% [markdown]
# **Q5) Which hotel has longer waiting time?**

# %%
temp_df = pd.DataFrame(grouped_by_hotel['days_in_waiting_list'].agg(np.mean).reset_index().rename(columns = {'days_in_waiting_list':'avg_waiting_period'}))
plt.figure(figsize = (8,5))
dfv = sns.barplot(x = temp_df['hotel'], y = temp_df['avg_waiting_period'] )
dfv.set(title='Avg Waiting Time by Hotel')
# Adding Value
for i in dfv.containers:
    dfv.bar_label(i,)
plt.show()

# %% [markdown]
# City hotel has significantly longer waiting time, hence City Hotel is much busier than Resort Hotel.

# %% [markdown]
# **Q6) Which hotel has higher bookings cancellation rate.**

# %%
# Selecting and counting number of cancelled bookings for each hotel.
cancelled_data = copy_hotel_df[copy_hotel_df['is_canceled'] == 1]
cancel_grp = cancelled_data.groupby('hotel')
d1 = pd.DataFrame(cancel_grp.size()).rename(columns = {0:'total_cancelled_bookings'})
d1
# Out:
#               total_cancelled_bookings
# hotel
# City Hotel                       16034
# Resort Hotel                      7974

# %%
# Counting total number of bookings for each type of hotel
grouped_by_hotel = copy_hotel_df.groupby('hotel')
total_booking = grouped_by_hotel.size()
d2 = pd.DataFrame(total_booking).rename(columns = {0: 'total_bookings'})
d2
# Out:
#               total_bookings
# hotel
# City Hotel             53273
# Resort Hotel           33956

# %%
d3 = pd.concat([d1,d2], axis = 1)

# Calculating cancel percentage 
d3['cancel_%'] = round((d3['total_cancelled_bookings']/d3['total_bookings'])*100,2)
d3
# Out:
#               total_cancelled_bookings  total_bookings  cancel_%
# hotel
# City Hotel                       16034           53273     30.10
# Resort Hotel                      7974           33956     23.48

# %%
plt.figure(figsize = (10,5))
dfv = sns.barplot(x = d3.index, y = d3['cancel_%'])
dfv.set(title = 'Cancellation Rate by Hotel')
# Adding Value
for i in dfv.containers:
    dfv.bar_label(i,)
plt.show()

# %% [markdown]
# Almost 30 % of City Hotel bookings got canceled.

# %% [markdown]
# **Q7) Which hotel has high chance that its customer will return for another stay?**

# %%
# Selecting and counting repeated customers bookings
repeated_data = copy_hotel_df[copy_hotel_df['is_repeated_guest'] == 1]
repeat_grp = repeated_data.groupby('hotel')
d1 = pd.DataFrame(repeat_grp.size()).rename(columns = {0:'total_repeated_guests'})
d1
# Out:
#               total_repeated_guests
# hotel
# City Hotel                     1657
# Resort Hotel                   1707

# %%
# Counting total bookings
total_booking = grouped_by_hotel.size()
d2 = pd.DataFrame(total_booking).rename(columns = {0: 'total_bookings'})
d2
# Out:
#               total_bookings
# hotel
# City Hotel             53273
# Resort Hotel           33956

# %%
d3 = pd.concat([d1,d2], axis = 1)

# Calculating repeat %
d3['repeat_%'] = round((d3['total_repeated_guests']/d3['total_bookings'])*100,2)
d3
# Out:
#               total_repeated_guests  total_bookings  repeat_%
# hotel
# City Hotel                     1657           53273      3.11
# Resort Hotel                   1707           33956      5.03

# %%
plt.figure(figsize = (10,5))
dfv= sns.barplot(x = d3.index, y = d3['repeat_%'])
dfv.set(title = 'Repetation % of customer by Hotel')
# Adding Value
for i in dfv.containers:
    dfv.bar_label(i,)
plt.show()

# %% [markdown]
# Both hotels have very small percentage that customer will repeat, but Resort hotel has slightly higher repeat % than City Hotel.

# %% [markdown]
# ## <b> (2) Distribution Channel wise Analysis </b>

# %% [markdown]
# **Q1) Which is the most common channel for booking hotels?**

# %%
group_by_dc = copy_hotel_df.groupby('distribution_channel')
temp_df = pd.DataFrame(round((group_by_dc.size()/copy_hotel_df.shape[0])*100,2)).reset_index().rename(columns = {0: 'Booking_%'})
plt.figure(figsize = (8,8))
plt.pie(x=temp_df['Booking_%'], autopct="%.2f%%", explode=[0.05]*5, labels=temp_df['distribution_channel'], pctdistance=0.5)
plt.title("Booking % by distribution channels", fontsize=15);

# %% [markdown]
# **Q2) Which channel is mostly used for early booking of hotels?**

# %%
group_by_dc = copy_hotel_df.groupby('distribution_channel')
temp_df = pd.DataFrame(round(group_by_dc['lead_time'].median(),2)).reset_index().rename(columns = {'lead_time': 'median_lead_time'})
plt.figure(figsize = (7,5))
dfv=sns.barplot(x = temp_df['distribution_channel'], y = temp_df['median_lead_time'])
dfv.set(title= 'Early Booking by Distribution Channel')
# Adding Value
for i in dfv.containers:
    dfv.bar_label(i,)
plt.show()

# %% [markdown]
# Travel Agent/ Travel Operator is mostly used for planning Hotel visits ahead of time. But for sudden visits other mediums are most preferred.

# %% [markdown]
# **Q3) Which channel has longer average waiting time?**

# %%
temp_df = pd.DataFrame(round((group_by_dc['days_in_waiting_list']).mean(),2)).reset_index().rename(columns = {'days_in_waiting_list': 'avg_waiting_time'})
plt.figure(figsize = (7,5))
dfv = sns.barplot(x = temp_df['distribution_channel'], y = temp_df['avg_waiting_time'])
dfv.set(title= 'Waiting Time by Distribution Channel', ylabel= 'avg_waiting_time(in days)')
# Adding Value
for i in dfv.containers:
    dfv.bar_label(i,)
plt.show()

# %% [markdown]
# While booking via TA/TO one may have to wait a little longer to confirm booking of rooms.

# %% [markdown]
# **Q4) Which distribution channel brings better revenue generating deals for hotels?**

# %%
group_by_dc_hotel = copy_hotel_df.groupby(['distribution_channel', 'hotel'])
temp_df = pd.DataFrame(round((group_by_dc_hotel['adr']).agg(np.mean),2)).reset_index().rename(columns = {'adr': 'avg_adr'})
plt.figure(figsize = (7,5))
sns.barplot(x = temp_df['distribution_channel'], y = temp_df['avg_adr'], hue = temp_df['hotel']).set(title = 'Avg ADR vs Distribution channel among Hotels')
plt.ylim(0,150)
plt.show()

# %% [markdown]
# GDS channel brings higher revenue generating deals for City hotel, in contrast to that most bookings come via TA/TO. City Hotel can work to increase outreach on GDS channels to get more higher revenue generating deals.
#
# Resort hotel has more revnue generating deals by direct and TA/TO channel. Resort Hotel need to increase outreach on GDS channel to increase revenue.

# %% [markdown]
# ## <b> (3) Booking cancellation Analysis </b>

# %% [markdown]
# Let us try to understand what causes the people to cancel the booking.

# %% [markdown]
# **Q1) Which significant distribution channel has highest cancellation percentage?**

# %%
temp_df = pd.DataFrame((group_by_dc['is_canceled'].sum()/group_by_dc.size())*100).drop(index = 'Undefined').reset_index().rename(columns = {0: 'Cancel_%'})
temp_df
# Out:
#   distribution_channel   Cancel_%
# 0            Corporate  12.761754
# 1               Direct  14.844836
# 2                  GDS  19.889503
# 3                TA/TO  31.000913

# %%
plt.figure(figsize = (8,5))
plt.pie( x = temp_df['Cancel_%'], labels = round(temp_df['Cancel_%'],1), explode=(0,0,0,0.1))
plt.title('Booking (%)age By Hotel')
plt.legend(temp_df['distribution_channel'], title = 'Distribution Channel', loc =10)
plt.show()

# %% [markdown]
# TA/TO has highest booking cancellation %. Therefore, a booking via TA/TO is 30% likely to get cancelled.

# %% [markdown]
# **Q2) What causes the cancelation of bookings of rooms by customers?**
#
#  One question can arise that may be longer waiting period or longer lead time causes the cancellation of bookings, let us check that.

# %%
waiting_bookings = copy_hotel_df[copy_hotel_df['days_in_waiting_list'] !=0]  # Selecting bookings with non zero waiting time

fig, axes = plt.subplots(1, 2, figsize=(18, 8))
sns.kdeplot(ax=axes[0],x = 'days_in_waiting_list', hue = 'is_canceled' , data = waiting_bookings).set(title='No. of Booking/Cancel vs Waiting Days')
sns.kdeplot(ax = axes[1], x = copy_hotel_df['lead_time'], hue = copy_hotel_df['is_canceled']).set(title='No. of Booking/Cancel vs Lead Time')
plt.show()

# %% [markdown]
# We see that most of the bookings that are cancelled have waiting period of less 150 days but also most of bookings that are not cancelled also have waiting period less than 150 days. Hence this shows that waiting period has no effect on cancellation of bookings. \
# \
# Also, lead time has no affect on cancellation of bookings, as both curves of cancelation and not cncelation are similar for lead time too.

# %% [markdown]
# Now we will check whether not getting allotted the same room type as demanded is the cause of cancellation of bookings

# %%
def check_room_allot(x):
  if x['reserved_room_type'] != x['assigned_room_type']:
    return 1
  else:
    return 0

copy_hotel_df['same_room_not_alloted'] = copy_hotel_df.apply(lambda x : check_room_allot(x), axis = 1)
grp_by_canc = copy_hotel_df.groupby('is_canceled')

temp_df = pd.DataFrame((grp_by_canc['same_room_not_alloted'].sum()/grp_by_canc.size())*100).rename(columns = {0: 'same_room_not_alloted_%'})
plt.figure(figsize = (8,4))
plt.pie(x = temp_df['same_room_not_alloted_%'],autopct='%1.2f%%', labels = ['yes', 'no'])
plt.title('same_room_not_alloted')
plt.show()

# %% [markdown]
# We see that not getting same room as demanded is not the case of cancellation of rooms. A significant percentage of bookings are not cancelled even after getting different room as demanded.

# %% [markdown]
# Lets see does not getting same room affects the adr.

# %%
plt.figure(figsize = (12,6))
sns.boxplot(x = 'same_room_not_alloted', y = 'adr', data = copy_hotel_df).set(title='Comparsion of ADR vs Same Room not Alloted')
plt.show()

# %% [markdown]
# So not getting same room do affects the adr, people who didn't got same room have paid a little lower adr, except for few exceptions.

# %% [markdown]
# ## <b> (4) Time wise analysis </b>

# %% [markdown]
# **Q1) which month results in high revenue?**

# %%
reindex = ['January', 'February','March','April','May','June','July','August','September','October','November','December']
copy_hotel_df['arrival_date_month'] = pd.Categorical(copy_hotel_df['arrival_date_month'],categories=reindex,ordered=True)
plt.figure(figsize = (15,8))
sns.boxplot(x = copy_hotel_df['arrival_date_month'],y = copy_hotel_df['adr']).set(title='Variation of Avg ADR entire year')
plt.show()

# %% [markdown]
# Avg adr rises from beginning of year upto middle of year and reaches peak at August and then lowers to the end of year. But hotels do make some good deals with high adr at end of year also.

# %% [markdown]
# **Q2) What is the booking %age of single, couple and family/friends?**

# %% [markdown]
# Let us divide our customers in three categories of single, couple and family/friends. then check their booking %

# %%
## Select single, couple, multiple adults and family
single   = not_canceled[(not_canceled['adults']==1) & (not_canceled['children']==0) & (not_canceled['babies']==0)]
couple   = not_canceled[(not_canceled['adults']==2) & (not_canceled['children']==0) & (not_canceled['babies']==0)]
family   = not_canceled[not_canceled['adults'] + not_canceled['children'] + not_canceled['babies'] > 2]

reindex = ['January', 'February','March','April','May','June','July','August','September','October','November','December']

fig, ax = plt.subplots(figsize=(12, 8))

for type in ['single', 'couple', 'family']:
  d1 = eval(type).groupby(['arrival_date_month']).size().reset_index().rename(columns = {0:'arrival_num'})
  d1['arrival_date_month'] = pd.Categorical(d1['arrival_date_month'],categories=reindex,ordered=True)
  sns.lineplot(data=d1, x= 'arrival_date_month', y='arrival_num', label=type, ax=ax).set(title='variation of No. of Customer month wise')
  
plt.grid()
plt.show()

# %% [markdown]
# Moslty bookings are done by couples(although we are not sure that they are couple as data doesn't tell about that)

# %% [markdown]
# It is clear from graph that their is a sudden surge in arrival num of couples and family in months of July and August. So better plans can be planned accordingly at that time for these type of customers.

# %% [markdown]
# **Q3) How long do people stay at the hotels?**

# %%
# Filtering not canceled booking
filter_df = copy_hotel_df['is_canceled'] == 0
data_df = copy_hotel_df[filter_df]

# Concatenating nights
data_df['total_nights'] = data_df['stays_in_weekend_nights'] + data_df['stays_in_week_nights']

# Working on stays
stay_df = data_df.groupby(['total_nights', 'hotel']).agg('count').reset_index()
stay_df = stay_df.iloc[:, :3]
stay_df = stay_df.rename(columns={'is_canceled':'Number of stays'})

# Ploting on Bar graph
plt.figure(figsize = (10,5))
sns.barplot(x = 'total_nights', y = 'Number of stays', data= stay_df, hue='hotel').set(title='No. of Stays vs Total Nights')
plt.legend(loc='upper right')
plt.show()
# Out:
# C:\Users\Rohit Kumar\AppData\Local\Temp\ipykernel_12924\1406090906.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df['total_nights'] = data_df['stays_in_weekend_nights'] + data_df['stays_in_week_nights']

# %% [markdown]
# Most people prefer to stay at the hotels of <=7 days.
